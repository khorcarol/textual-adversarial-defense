# %%
import time

t=time.time()
import datasets
print(time.time()-t)
# Out:
# 0.00013518333435058594

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained(
 "textattack/roberta-base-SST-2"
)

special_chars = {
    # Variation selectors (U+FE00–U+FE0F, U+E0100–U+E01EF)
    # "variation_selectors": [chr(cp) for cp in list(range(0xFE00, 0xFE10)) + list(range(0xE0100, 0xE01F0))],

    # Unicode “tag” characters (U+E0000–U+E001F)
    "tag_characters": [chr(0xE0000 + i) for i in range(32)],

    # # Typical invisible characters
    # "invisible_characters": [
    #     "\u200B",  # zero-width space
    #     "\u200C",  # zero-width non-joiner
    #     "\u200D",  # zero-width joiner
    #     "\u061C",  # Arabic letter mark
    #     "\u180E",  # Mongolian vowel separator
    # ],

    # # Bidi control characters
    # "bidi_characters": [
    #     "\u202A", "\u202B", "\u202C", "\u202D", "\u202E"
    # ],
    
    # "deletion_character": ["\u0008"]

}

for category, chars in special_chars.items():
    for char in chars:
        enc = tokenizer(
            char,
            return_tensors="pt",   # or "tf"/"np"
            truncation=True,
            max_length=128
        )
        print(f"Category: {category}, Char: {repr(char)}, Encoded: {enc}")
# Out:
# Category: tag_characters, Char: '\U000e0000', Encoded: {'input_ids': tensor([[    0, 49078, 21402,  7471,  7471,     2]]), 'attention_mask': tensor([[1, 1, 1, 1, 1, 1]])}
# Category: tag_characters, Char: '\U000e0001', Encoded: {'input_ids': tensor([[    0, 49078, 21402,  7471, 10172,     2]]), 'attention_mask': tensor([[1, 1, 1, 1, 1, 1]])}
# Category: tag_characters, Char: '\U000e0002', Encoded: {'input_ids': tensor([[    0, 49078, 21402,  7471,  9264,     2]]), 'attention_mask': tensor([[1, 1, 1, 1, 1, 1]])}
# Category: tag_characters, Char: '\U000e0003', Encoded: {'input_ids': tensor([[    0, 49078, 21402,  7471,   862,     2]]), 'attention_mask': tensor([[1, 1, 1, 1, 1, 1]])}
# Category: tag_characters, Char: '\U000e0004', Encoded: {'input_ids': tensor([[    0, 49078, 21402,  7471, 11936,     2]]), 'attention_mask': tensor([[1, 1, 1, 1, 1, 1]])}
# Category: tag_characters, Char: '\U000e0005', Encoded: {'input_ids': tensor([[    0, 49078, 21402,  7471,  5782,     2]]), 'attention_mask': tensor([[1, 1, 1, 1, 1, 1]])}
# Category: tag_characters, Char: '\U000e0006', Encoded: {'input_ids': tensor([[    0, 49078, 21402,  7471, 27819,     2]]), 'attention_mask': tensor([[1, 1, 1, 1, 1, 1]])}
# Category: tag_characters, Char: '\U000e0007', Encoded: {'input_ids': tensor([[    0, 49078, 21402,  7471,  6382,     2]]), 'attention_mask': tensor([[1, 1, 1, 1, 1, 1]])}
# Category: tag_characters, Char: '\U000e0008', Encoded: {'input_ids': tensor([[    0, 49078, 21402,  7471, 23133,     2]]), 'attention_mask': tensor([[1, 1, 1, 1, 1, 1]])}
# Category: tag_characters, Char: '\U000e0009', Encoded: {'input_ids': tensor([[    0, 49078, 21402,  7471, 23171,     2]]), 'attention_mask': tensor([[1, 1, 1, 1, 1, 1]])}
# Category: tag_characters, Char: '\U000e000a', Encoded: {'input_ids': tensor([[    0, 49078, 21402,  7471, 27969,     2]]), 'attention_mask': tensor([[1, 1, 1, 1, 1, 1]])}
# Category: tag_characters, Char: '\U000e000b', Encoded: {'input_ids': tensor([[    0, 49078, 21402,  7471, 13859,     2]]), 'attention_mask': tensor([[1, 1, 1, 1, 1, 1]])}
# Category: tag_characters, Char: '\U000e000c', Encoded: {'input_ids': tensor([[    0, 49078, 21402,  7471, 14285,     2]]), 'attention_mask': tensor([[1, 1, 1, 1, 1, 1]])}
# Category: tag_characters, Char: '\U000e000d', Encoded: {'input_ids': tensor([[    0, 49078, 21402,  7471,  8384,     2]]), 'attention_mask': tensor([[1, 1, 1, 1, 1, 1]])}
# Category: tag_characters, Char: '\U000e000e', Encoded: {'input_ids': tensor([[    0, 49078, 21402,  7471, 12736,     2]]), 'attention_mask': tensor([[1, 1, 1, 1, 1, 1]])}
# Category: tag_characters, Char: '\U000e000f', Encoded: {'input_ids': tensor([[    0, 49078, 21402,  7471,  9357,     2]]), 'attention_mask': tensor([[1, 1, 1, 1, 1, 1]])}
# Category: tag_characters, Char: '\U000e0010', Encoded: {'input_ids': tensor([[    0, 49078, 21402,  7471, 16948,     2]]), 'attention_mask': tensor([[1, 1, 1, 1, 1, 1]])}
# Category: tag_characters, Char: '\U000e0011', Encoded: {'input_ids': tensor([[    0, 49078, 21402,  7471,  3602,     2]]), 'attention_mask': tensor([[1, 1, 1, 1, 1, 1]])}
# Category: tag_characters, Char: '\U000e0012', Encoded: {'input_ids': tensor([[    0, 49078, 21402,  7471, 10659,     2]]), 'attention_mask': tensor([[1, 1, 1, 1, 1, 1]])}
# Category: tag_characters, Char: '\U000e0013', Encoded: {'input_ids': tensor([[    0, 49078, 21402,  7471,  9085,     2]]), 'attention_mask': tensor([[1, 1, 1, 1, 1, 1]])}
# Category: tag_characters, Char: '\U000e0014', Encoded: {'input_ids': tensor([[    0, 49078, 21402,  7471, 10674,     2]]), 'attention_mask': tensor([[1, 1, 1, 1, 1, 1]])}
# Category: tag_characters, Char: '\U000e0015', Encoded: {'input_ids': tensor([[    0, 49078, 21402,  7471, 15722,     2]]), 'attention_mask': tensor([[1, 1, 1, 1, 1, 1]])}
# Category: tag_characters, Char: '\U000e0016', Encoded: {'input_ids': tensor([[    0, 49078, 21402,  7471, 25448,     2]]), 'attention_mask': tensor([[1, 1, 1, 1, 1, 1]])}
# Category: tag_characters, Char: '\U000e0017', Encoded: {'input_ids': tensor([[    0, 49078, 21402,  7471,  6800,     2]]), 'attention_mask': tensor([[1, 1, 1, 1, 1, 1]])}
# Category: tag_characters, Char: '\U000e0018', Encoded: {'input_ids': tensor([[    0, 49078, 21402,  7471,   711,     2]]), 'attention_mask': tensor([[1, 1, 1, 1, 1, 1]])}
# Category: tag_characters, Char: '\U000e0019', Encoded: {'input_ids': tensor([[    0, 49078, 21402,  7471,    27,     2]]), 'attention_mask': tensor([[1, 1, 1, 1, 1, 1]])}
# Category: tag_characters, Char: '\U000e001a', Encoded: {'input_ids': tensor([[    0, 49078, 21402,  7471, 15113,     2]]), 'attention_mask': tensor([[1, 1, 1, 1, 1, 1]])}
# Category: tag_characters, Char: '\U000e001b', Encoded: {'input_ids': tensor([[    0, 49078, 21402,  7471,  3726,     2]]), 'attention_mask': tensor([[1, 1, 1, 1, 1, 1]])}
# Category: tag_characters, Char: '\U000e001c', Encoded: {'input_ids': tensor([[    0, 49078, 21402,  7471,    48,     2]]), 'attention_mask': tensor([[1, 1, 1, 1, 1, 1]])}
# Category: tag_characters, Char: '\U000e001d', Encoded: {'input_ids': tensor([[    0, 49078, 21402,  7471,    46,     2]]), 'attention_mask': tensor([[1, 1, 1, 1, 1, 1]])}
# Category: tag_characters, Char: '\U000e001e', Encoded: {'input_ids': tensor([[    0, 49078, 21402,  7471, 17772,     2]]), 'attention_mask': tensor([[1, 1, 1, 1, 1, 1]])}
# Category: tag_characters, Char: '\U000e001f', Encoded: {'input_ids': tensor([[    0, 49078, 21402,  7471,  4333,     2]]), 'attention_mask': tensor([[1, 1, 1, 1, 1, 1]])}
